# %%
from preprocessing import split_files
# %load_ext autoreload
# %autoreload 2

# %%
split_files('/home/thomasaqa/atiam/informatique musicale/machine learning/projet/dataset/dataset_1/wav_files/',5,'/home/thomasaqa/atiam/informatique musicale/machine learning/projet/dataset/dataset_1/wav_files_cut/',22050,make_mono=True)
# Out:
# Splitting 13_rock_120_beat_4-4.wav
# Splitting 180_afrocuban_105_fill_4-4.wav
# Audio file lasts less than 5 seconds.
# Splitting 183_afrocuban_105_beat_4-4.wav
# Splitting 80_country_78_beat_4-4.wav
# Splitting 67_rock_145_fill_4-4.wav
# Audio file lasts less than 5 seconds.
# Splitting 154_soul_98_fill_4-4.wav
# Audio file lasts less than 5 seconds.
# Splitting 20_rock-shuffle_112_beat_4-4.wav
# Splitting 2_jazz-swing_215_beat_4-4.wav
# Splitting 87_hiphop_75_beat_4-4.wav
# Splitting 106_soul-motown_104_beat_4-4.wav
# Splitting 102_hiphop_70_fill_4-4.wav
# Audio file lasts less than 5 seconds.
# Splitting 5_rock_86_fill_4-4.wav
# Audio file lasts less than 5 seconds.
# Splitting 128_hiphop_140_fill_4-4.wav
# Splitting 13_rock_140_beat_4-4.wav
# Splitting 165_latin-brazilian-baiao_95_fill_4-4.wav
# Audio file lasts less than 5 seconds.
# Splitting 252_funk-purdieshuffle_130_fill_4-4.wav
# Audio file lasts less than 5 seconds.
# Splitting 60_punk_128_fill_4-4.wav
# ...
